# %%
import simplipy

# %%
engine = simplipy.SimpliPyEngine.load('dev_7-3')

# %%
engine.simplify('pow2(abs(x1 / 2)) + <constant> * exp(neg(inv(x2 - x2))) + <constant>', mask_elementary_literals=False)
# Out:
# '<constant> + (x1 / 2)**2'
