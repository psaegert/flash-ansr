# %%
from flash_ansr.utils import substitute_root_path, load_config, save_config

# %%
config = load_config(r'{{ROOT}}/configs/v19.1-8M/train.yaml')
config
# Out:
# {'model': '/home/psaegert/Projects/flash-ansr/configs/v19.1-8M/model.yaml',
#  'optimizer': {'name': 'AdamW',
#   'kwargs': {'lr': 1, 'weight_decay': 0.01, 'betas': [0.9, 0.95]}},
#  'lr_schedule': [[0, 0.0], [200000, '1e-4']],
#  'batch_size': 128,
#  'train_dataset': '/home/psaegert/Projects/flash-ansr/configs/v19.1-8M/dataset_train.yaml',
#  'val_dataset': '/home/psaegert/Projects/flash-ansr/configs/v19.1-8M/dataset_val.yaml',
#  'val_batch_size': 128,
#  'val_size': 100000,
#  'compile_mode': 'reduce-overhead',
#  'gradient_checkpointing': False,
#  'wandb_watch_log': None,
#  'wandb_watch_log_freq': 1000,
#  'steps': 2000000,
#  'device': 'cuda'}

# %%
save_config(config, directory=substitute_root_path(r'{{ROOT}}/experimental/troubleshoot/relative_config'),
            filename='train.yaml', recursive=True, resolve_paths=True, reference='relative')
