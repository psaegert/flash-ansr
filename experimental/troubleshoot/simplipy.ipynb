# %%
import simplipy as sp
from flash_ansr import get_path, load_config

# %%
engine = sp.SimpliPyEngine.from_config(load_config(get_path('configs', 'v15.0', 'simplipy_engine.yaml')))

# %%
engine.simplify(['-', 'x2', '/', '-', 'x4', '+', '+', 'x6', '/', 'x4', 'x4', 'x4', 'x5'], verbose=True)
# Out:
# Initial expression: ['-', 'x2', '/', '-', 'x4', '+', '+', 'x6', '/', 'x4', 'x4', 'x4', 'x5']
# ---- / ----
# 0
# [{'add': {('x4',): [1, 0]}, 'mult': {('x4',): [1, 0]}}]
# Initializing ('x4',) for mult
# Adding 1 to 0 at 0 of ('x4',)
# Adding 0 to 0 at 1 of ('x4',)
# 1
# [{'add': {('x4',): [1, 0]}, 'mult': {('x4',): [1, 0]}}]
# Adding 1 to 0 at 1 of ('x4',) (reversed)
# Adding 0 to 1 at 0 of ('x4',) (reversed)
# /---- / ----
#
# ---- + ----
# 0
# [{'add': {('x6',): [1, 0]}, 'mult': {('x6',): [1, 0]}}]
# Initializing ('x6',) for add
# Adding 1 to 0 at 0 of ('x6',)
# Adding 0 to 0 at 1 of ('x6',)
# 1
# [{'add': {}, 'mult': {('x4',): [1, 1]}},
#  [[{'add': {('x4',): [1, 0]}, 'mult': {('x4',): [1, 0]}}],
#   [{'add': {('x4',): [1, 0]}, 'mult': {('x4',): [1, 0]}}]]]
# /---- + ----
#
# ---- + ----
# 0
# [{'add': {('x6',): [1, 0]}, 'mult': {}},
#  [[{'add': {('x6',): [1, 0]}, 'mult': {('x6',): [1, 0]}}],
#   [{'add': {}, 'mult': {('x4',): [1, 1]}},
# ...
